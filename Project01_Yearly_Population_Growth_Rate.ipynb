# %%
import matplotlib.pyplot as plt
import csv

# %%
# !wget -O Population.csv https://raw.githubusercontent.com/JavohirJalilov/AI-Matplotlib/master/dataset/Yearly%20Population%20Growth%20Rate.csv
# Out:
# --2022-08-05 12:12:23--  https://raw.githubusercontent.com/JavohirJalilov/AI-Matplotlib/master/dataset/Yearly%20Population%20Growth%20Rate.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 175 [text/plain]
# Saving to: ‘Population.csv’
#
# Population.csv      100%[===================>]     175  --.-KB/s    in 0s
#
# 2022-08-05 12:12:24 (6.49 MB/s) - ‘Population.csv’ saved [175/175]

# %%
def read_data(filename):
  """
  Read csv file
  Args:
    file_path(str): file path
  Returns:
    list: data split row
  """
  # WRITE YOUR CODE HERE

# %%
data_list = read_data("Population.csv")

# %%
def get_data(data_list):
  """
  Get data from list.

  Args:
    data(list): data split row
  Returns:
    tuple: labels, points
  """
  # WRITE YOUR CODE HERE

# %%
labels, points = get_data(data_list)

# %%
def plot_data(points):
  """
  Show data.
  Args:
    points(list): growth, populationßß
  Returns:
    None
  """

  # WRITE YOUR CODE HERE

# %%
plt.figure(dpi=100)
plot_data(labels, points)
