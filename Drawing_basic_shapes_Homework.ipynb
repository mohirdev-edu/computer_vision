# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

# %%
image = np.full((1000,1000,3),255,dtype=np.uint8)
cv.imwrite('image_draw.png',image)
# Out:
# True

# %%
def bounding_box1(img,start_point,end_point,color):
  '''
  Draw bounding box
  '''
  # CODE
  plt.imshow(img)
  plt.show()

img = cv.imread('image_draw.png')
bounding_box1(img,(200,200),(800,800),(0, 0, 255))

# %%
def bounding_box2(img,start_point,end_point,color):
  '''
  Draw bounding box
  '''
  # CODE
  plt.imshow(img)
  plt.show()

img = cv.imread('image_draw.png')
bounding_box2(img,(200,200),(800,800),(255, 0, 0))

# %%
def bounding_box3(img,start_point,end_point,color):
  '''
  Draw bounding box
  '''
  # CODE
  plt.imshow(img)
  plt.show()

img = cv.imread('image_draw.png')
bounding_box3(img,(200,200),(800,800),(227, 220, 220))

# %%
def bounding_box4(img,start_point,end_point,color):
  '''
  Draw bounding box
  '''
  # CODE
  plt.imshow(img)
  plt.show()

img = cv.imread('image_draw.png')
bounding_box4(img,(200,300),(800,700),(255, 0, 0))

# %%
def draw_triangle(img):
  '''
  Drawing triangle
  '''
  # CODE
  plt.imshow(img)
  plt.show()

img = cv.imread('image_draw.png')
draw_triangle(img)

# %%
def draw_rhombus(img):
  '''
  Drawing rhombus
  '''
  # CODE
  plt.imshow(img)
  plt.show()

img = cv.imread('image_draw.png')
draw_rhombus(img)

# %%
def windows_logo(img):
  '''
  Drawing windows logo
  '''
  # CODE
  plt.imshow(img)
  plt.show

img = cv.imread('image_draw.png')
windows_logo(img)

# %%
def circles(img):
  # CODE

  plt.imshow(img)
  plt.show()

img = cv.imread('image_draw.png')
circles(img)

# %%
# !wget -O mac.jpg https://lamanzanamordida.net/app/uploads-lamanzanamordida.net/2020/07/Mac.jpg
# Out:
# --2021-05-04 19:50:54--  https://lamanzanamordida.net/app/uploads-lamanzanamordida.net/2020/07/Mac.jpg
# Resolving lamanzanamordida.net (lamanzanamordida.net)... 51.81.243.73, 51.81.66.107, 74.208.135.112, ...
# Connecting to lamanzanamordida.net (lamanzanamordida.net)|51.81.243.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75103 (73K) [image/jpeg]
# Saving to: ‘mac.jpg’
#
# mac.jpg             100%[===================>]  73.34K   458KB/s    in 0.2s
#
# 2021-05-04 19:50:55 (458 KB/s) - ‘mac.jpg’ saved [75103/75103]

# %%
img_mac = cv.imread('mac.jpg')
img_mac = cv.cvtColor(img_mac,cv.COLOR_BGR2RGB)

# %%
def bounding_box_glasses(img,color):
  # CODE
  plt.imshow(img)
  plt.show()

bounding_box_glasses(img_mac,(0,0,255))
