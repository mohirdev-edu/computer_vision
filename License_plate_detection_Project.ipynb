# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pathlib

plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

# %%
# !wget https://raw.githubusercontent.com/JavohirJalilov/OpenCV/master/CARS/img13.png
# Out:
# --2022-10-19 16:19:16--  https://raw.githubusercontent.com/JavohirJalilov/OpenCV/master/CARS/img13.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 603805 (590K) [image/png]
# Saving to: ‘img13.png’
#
# img13.png           100%[===================>] 589.65K  --.-KB/s    in 0.04s
#
# 2022-10-19 16:19:16 (13.4 MB/s) - ‘img13.png’ saved [603805/603805]

# %%
#utility
def show(img,s=8):
  plt.figure(figsize=(s,s),dpi=100)
  plt.imshow(img,cmap='gray')
  plt.show()

# %%
def get_img(filename):
  '''
  name: image name
  return:
    tuple: grayscale image, RGB image
  '''
  # WRITE YOUR CODE HERE
  return img

# %%
def kernal(x,y):
  k = np.ones((x,y),dtype=np.uint8)
  return k

# %%
def max_index(contours):
  '''
  Find the contour index with the largest area
  '''
  # WRITE YOUR CODE HERE
  return max_idx

# %%
show(get_img('/content/img13.png'))

# %%
def license_detection(image):
  '''
  Car image License plate bounding box
  '''
  # WRITE YOUR CODE HERE
  show(image)

# %%
img = get_img('/content/img13.png')

# %%
license_detection(img)
