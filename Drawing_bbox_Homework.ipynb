# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.right'] = plt.rcParams['ytick.labelright'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

# %%
# !wget https://github.com/Naxalov/ComputerVision/raw/master/ROAD/road_signs/bus_stop/bus_stop.png
# Out:
# --2022-07-05 05:05:07--  https://github.com/Naxalov/ComputerVision/raw/master/ROAD/road_signs/bus_stop/bus_stop.png
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Naxalov/ComputerVision/master/ROAD/road_signs/bus_stop/bus_stop.png [following]
# --2022-07-05 05:05:07--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/ROAD/road_signs/bus_stop/bus_stop.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 251249 (245K) [image/png]
# Saving to: ‘bus_stop.png.1’
#
# bus_stop.png.1      100%[===================>] 245.36K  --.-KB/s    in 0.002s
#
# ...

# %% [markdown]
# 1. Draw a bbox using points in Pascal VOC format.
#
# <b>Input</b>
#   <table align="left">
#   <tr>
#     <th><font size="3">x1</font></th>
#     <th><font size="3">y1</font></th>
#     <th><font size="3">x2</font></th>
#     <th><font size="3">y2</font></th>
#   </tr>
#   <tr>
#     <td><font size="3">1617</font></td>
#     <td><font size="3">103</font></td>
#     <td><font size="3">1879</font></td>
#     <td><font size="3">346</font></td>
#   </tr>
#   </table>

# %%
def bbox_pascal_voc(image, x1, y1, x2, y2):
  """
  Draw a bbox using points in Pascal VOC format.

  Arguments:
    image: numpy array
    x1(int): top left point
    y1(int): top left point
    x2(int): bottom right point
    y2(int): bottom right point
  Returns:
    None: Plot bbox
  """
  # WRITE YOUR CODE HERE

# %%
image = cv2.imread('bus_stop.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(dpi=150)
# WRITE YOUR CODE HERE

# %% [markdown]
# 1. Draw a bbox using points in Pascal VOC format.
#
# <b>Input</b>
#   <table align="left">
#   <tr>
#     <th><font size="3">x</font></th>
#     <th><font size="3">y</font></th>
#     <th><font size="3">w</font></th>
#     <th><font size="3">h</font></th>
#   </tr>
#   <tr>
#     <td><font size="3">244</font></td>
#     <td><font size="3">434</font></td>
#     <td><font size="3">508</font></td>
#     <td><font size="3">238</font></td>
#   </tr>
#   </table>

# %%
def bbox_coco(image, x, y, w, h):
  """
  Draw a bbox using points in Pascal VOC format.

  Arguments:
    image: numpy array
    x1(int): top left point
    y1(int): top left point
    x2(int): bottom right point
    y2(int): bottom right point
  Returns:
    None: Plot bbox
  """
  # WRITE YOUR CODE HERE

# %%
image = cv2.imread('bus_stop.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(dpi=150)
bbox_coco(image,244,434,508,238)
