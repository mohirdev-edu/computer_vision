# %%
# !wget -O img.jpg https://github.com/Naxalov/ComputerVision/raw/master/shape%20detection/00_primitive_shapes_different_colors.png
# Out:
# --2021-06-01 17:34:08--  https://github.com/Naxalov/ComputerVision/raw/master/shape%20detection/00_primitive_shapes_different_colors.png
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Naxalov/ComputerVision/master/shape%20detection/00_primitive_shapes_different_colors.png [following]
# --2021-06-01 17:34:08--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/shape%20detection/00_primitive_shapes_different_colors.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4972 (4.9K) [image/png]
# Saving to: ‘img.jpg’
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

# %%
# utility
def show(img,s=8,b=False):
  plt.figure(figsize=(s,s))
  plt.imshow(img,cmap='gray')
  plt.grid(alpha=.2)
  plt.grid(b)
  plt.show()

# %%
def get_img(filename):
  img = cv2.imread(filename)
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
  return img,gray

# %%
img,gray = get_img('img.jpg')

# %%
_,thresh = #Threshold value

# %%
show(thresh)

# %%
contours,heirarchy = cv2.findContours(thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)

# %%
def shape_detaction(img,contours):
  '''
  Create a shape recognition program

  img: RGB image.
  contours: Detected contours.
  '''
  # CODE

  return img

# %%
drawing_img = img.copy()
drawing_img = shape_detaction(drawing_img,contours)

# %%
show(drawing_img)
