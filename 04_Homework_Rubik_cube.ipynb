# %%
# !wget -O cube.png https://github.com/Naxalov/ComputerVision/raw/master/Rubik_Cube/2.png
# Out:
# --2022-10-13 18:00:23--  https://github.com/Naxalov/ComputerVision/raw/master/Rubik_Cube/2.png
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Naxalov/ComputerVision/master/Rubik_Cube/2.png [following]
# --2022-10-13 18:00:23--  https://raw.githubusercontent.com/Naxalov/ComputerVision/master/Rubik_Cube/2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 858445 (838K) [image/png]
# Saving to: ‘cube.png’
#
# cube.png            100%[===================>] 838.33K  --.-KB/s    in 0.05s
#
# 2022-10-13 18:00:23 (17.8 MB/s) - ‘cube.png’ saved [858445/858445]

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import json
from random import randint


plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = False
plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

# %%
def show(img,s=8):
  plt.figure(figsize=(s,s),dpi=100)
  plt.imshow(img,cmap='gray')
  plt.show()

# %%
def get_img(fname):

  img = cv2.imread(fname)
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
  return img,gray

# %%
img,gray = get_img('cube.png')

# %%
show(img,s=5)

# %%
def ROI_image(mask_img,img):
  # CODE
  return ROI_img

# %%
img_blue = cv2.inRange(gray,'start color','stop color')
img_red = cv2.inRange(gray,'start color','stop color')
img_dark_yellow = cv2.inRange(gray,'start color','stop color')
img_green = cv2.inRange(gray,'start color','stop color')
img_yellow = cv2.inRange(gray,'start color','stop color'
img_white = cv2.inRange(gray,'start color','stop color')
show(img_white,s=5)

# %%
ROI_blue = ROI_image(img_blue,img)
ROI_red = ROI_image(img_red,img)
ROI_dark_yellow = ROI_image(img_dark_yellow,img)
ROI_green = ROI_image(img_green,img)
ROI_yellow = ROI_image(img_yellow,img)
ROI_white = ROI_image(img_white,img)

# %%
add_img = np.hstack((ROI_blue,ROI_red,ROI_dark_yellow,ROI_green,ROI_yellow,ROI_white))

# %%
show(add_img)
